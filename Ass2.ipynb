# %%
#import required libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentPerformance.csv")
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           79             77           75.0            100.0          2019.0
# 1           74             86           69.0             75.0             NaN
# 2           75             93           65.0             75.0          2021.0
# 3           63             84           76.0             90.0          2019.0
# 4           71             80            NaN             79.0          2020.0
# 5           90             92           64.0             89.0          2021.0
# 6           64             92           80.0            200.0          2020.0
# 7           50             98           80.0             81.0          2020.0
# 8           72             91           71.0             78.0          2018.0
# 9           76             87           76.0             80.0          2018.0
# 10          60             86           75.0             95.0          2019.0
# 11          76             97           60.0             84.0          2018.0
# 12          63             91           75.0             94.0          2018.0
# 13          62            100            NaN             82.0          2018.0
# 14          76             75           71.0              NaN          2020.0
# 15          73             98           61.0             92.0          2018.0
# 16          79             78           74.0             81.0          2019.0
# 17          63             97           68.0             81.0          2019.0
# 18          78             97           62.0             89.0          2021.0
# 19          69             94           67.0             96.0             NaN
# 20          60             90           63.0            100.0          2019.0
# 21          79             97           25.0             76.0          2020.0
# 22          77             90           71.0             84.0          2020.0
# 23          74             75           69.0              NaN          2019.0
# 24          78             98           61.0             96.0          2018.0
# 25          60             91           79.0             81.0          2021.0
# 26          71             77           74.0             84.0          2018.0
# 27          73             84            NaN             88.0          2021.0
# 28          66             94           62.0             82.0          2021.0
#
#     placement_offer_count
# 0                     3.0
# 1                     2.0
# 2                     2.0
# 3                     3.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     2.0
# 8                     2.0
# 9                     2.0
# 10                    3.0
# 11                    2.0
# 12                    3.0
# 13                    2.0
# 14                    1.0
# 15                    3.0
# 16                    NaN
# 17                    2.0
# 18                    3.0
# 19                    3.0
# 20                    3.0
# 21                    2.0
# 22                    2.0
# 23                    1.0
# 24                    3.0
# 25                    2.0
# 26                    2.0
# 27                    3.0
# 28                    2.0

# %%
df.shape
# Out:
# (29, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   math_score             29 non-null     int64
#  1   reading_score          29 non-null     int64
#  2   writing_score          26 non-null     float64
#  3   placement_score        27 non-null     float64
#  4   club_join_year         27 non-null     float64
#  5   placement_offer_count  28 non-null     float64
# dtypes: float64(4), int64(2)
# memory usage: 1.5 KB

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            3
# placement_score          2
# club_join_year           2
# placement_offer_count    1
# dtype: int64

# %%
df['writing_score'] = df['writing_score'].fillna(method='ffill')
df
# Out:
# C:\Users\HARSH\AppData\Local\Temp\ipykernel_8404\2262822741.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['writing_score'] = df['writing_score'].fillna(method='ffill')
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           79             77           75.0            100.0          2019.0
# 1           74             86           69.0             75.0             NaN
# 2           75             93           65.0             75.0          2021.0
# 3           63             84           76.0             90.0          2019.0
# 4           71             80           76.0             79.0          2020.0
# 5           90             92           64.0             89.0          2021.0
# 6           64             92           80.0            200.0          2020.0
# 7           50             98           80.0             81.0          2020.0
# 8           72             91           71.0             78.0          2018.0
# 9           76             87           76.0             80.0          2018.0
# 10          60             86           75.0             95.0          2019.0
# 11          76             97           60.0             84.0          2018.0
# 12          63             91           75.0             94.0          2018.0
# 13          62            100           75.0             82.0          2018.0
# 14          76             75           71.0              NaN          2020.0
# 15          73             98           61.0             92.0          2018.0
# 16          79             78           74.0             81.0          2019.0
# 17          63             97           68.0             81.0          2019.0
# 18          78             97           62.0             89.0          2021.0
# 19          69             94           67.0             96.0             NaN
# 20          60             90           63.0            100.0          2019.0
# 21          79             97           25.0             76.0          2020.0
# 22          77             90           71.0             84.0          2020.0
# 23          74             75           69.0              NaN          2019.0
# 24          78             98           61.0             96.0          2018.0
# 25          60             91           79.0             81.0          2021.0
# 26          71             77           74.0             84.0          2018.0
# 27          73             84           74.0             88.0          2021.0
# 28          66             94           62.0             82.0          2021.0
#
#     placement_offer_count
# 0                     3.0
# 1                     2.0
# 2                     2.0
# 3                     3.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     2.0
# 8                     2.0
# 9                     2.0
# 10                    3.0
# 11                    2.0
# 12                    3.0
# 13                    2.0
# 14                    1.0
# 15                    3.0
# 16                    NaN
# 17                    2.0
# 18                    3.0
# 19                    3.0
# 20                    3.0
# 21                    2.0
# 22                    2.0
# 23                    1.0
# 24                    3.0
# 25                    2.0
# 26                    2.0
# 27                    3.0
# 28                    2.0

# %%
df['placement_score'] = df['placement_score'].fillna(method = 'bfill')
#df.isnull().sum()
df
# Out:
# C:\Users\HARSH\AppData\Local\Temp\ipykernel_8404\1889915476.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['placement_score'] = df['placement_score'].fillna(method = 'bfill')
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           79             77           75.0            100.0          2019.0
# 1           74             86           69.0             75.0             NaN
# 2           75             93           65.0             75.0          2021.0
# 3           63             84           76.0             90.0          2019.0
# 4           71             80           76.0             79.0          2020.0
# 5           90             92           64.0             89.0          2021.0
# 6           64             92           80.0            200.0          2020.0
# 7           50             98           80.0             81.0          2020.0
# 8           72             91           71.0             78.0          2018.0
# 9           76             87           76.0             80.0          2018.0
# 10          60             86           75.0             95.0          2019.0
# 11          76             97           60.0             84.0          2018.0
# 12          63             91           75.0             94.0          2018.0
# 13          62            100           75.0             82.0          2018.0
# 14          76             75           71.0             92.0          2020.0
# 15          73             98           61.0             92.0          2018.0
# 16          79             78           74.0             81.0          2019.0
# 17          63             97           68.0             81.0          2019.0
# 18          78             97           62.0             89.0          2021.0
# 19          69             94           67.0             96.0             NaN
# 20          60             90           63.0            100.0          2019.0
# 21          79             97           25.0             76.0          2020.0
# 22          77             90           71.0             84.0          2020.0
# 23          74             75           69.0             96.0          2019.0
# 24          78             98           61.0             96.0          2018.0
# 25          60             91           79.0             81.0          2021.0
# 26          71             77           74.0             84.0          2018.0
# 27          73             84           74.0             88.0          2021.0
# 28          66             94           62.0             82.0          2021.0
#
#     placement_offer_count
# 0                     3.0
# 1                     2.0
# 2                     2.0
# 3                     3.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     2.0
# 8                     2.0
# 9                     2.0
# 10                    3.0
# 11                    2.0
# 12                    3.0
# 13                    2.0
# 14                    1.0
# 15                    3.0
# 16                    NaN
# 17                    2.0
# 18                    3.0
# 19                    3.0
# 20                    3.0
# 21                    2.0
# 22                    2.0
# 23                    1.0
# 24                    3.0
# 25                    2.0
# 26                    2.0
# 27                    3.0
# 28                    2.0

# %%
df['club_join_year'] = df['club_join_year'].replace(to_replace=np.nan, value='2019')
df
# Out:
#     math_score  reading_score  writing_score  placement_score club_join_year  \
# 0           79             77           75.0            100.0         2019.0
# 1           74             86           69.0             75.0           2019
# 2           75             93           65.0             75.0         2021.0
# 3           63             84           76.0             90.0         2019.0
# 4           71             80           76.0             79.0         2020.0
# 5           90             92           64.0             89.0         2021.0
# 6           64             92           80.0            200.0         2020.0
# 7           50             98           80.0             81.0         2020.0
# 8           72             91           71.0             78.0         2018.0
# 9           76             87           76.0             80.0         2018.0
# 10          60             86           75.0             95.0         2019.0
# 11          76             97           60.0             84.0         2018.0
# 12          63             91           75.0             94.0         2018.0
# 13          62            100           75.0             82.0         2018.0
# 14          76             75           71.0             92.0         2020.0
# 15          73             98           61.0             92.0         2018.0
# 16          79             78           74.0             81.0         2019.0
# 17          63             97           68.0             81.0         2019.0
# 18          78             97           62.0             89.0         2021.0
# 19          69             94           67.0             96.0           2019
# 20          60             90           63.0            100.0         2019.0
# 21          79             97           25.0             76.0         2020.0
# 22          77             90           71.0             84.0         2020.0
# 23          74             75           69.0             96.0         2019.0
# 24          78             98           61.0             96.0         2018.0
# 25          60             91           79.0             81.0         2021.0
# 26          71             77           74.0             84.0         2018.0
# 27          73             84           74.0             88.0         2021.0
# 28          66             94           62.0             82.0         2021.0
#
#     placement_offer_count
# 0                     3.0
# 1                     2.0
# 2                     2.0
# 3                     3.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     2.0
# 8                     2.0
# 9                     2.0
# 10                    3.0
# 11                    2.0
# 12                    3.0
# 13                    2.0
# 14                    1.0
# 15                    3.0
# 16                    NaN
# 17                    2.0
# 18                    3.0
# 19                    3.0
# 20                    3.0
# 21                    2.0
# 22                    2.0
# 23                    1.0
# 24                    3.0
# 25                    2.0
# 26                    2.0
# 27                    3.0
# 28                    2.0

# %%
df['club_join_year'] = df['club_join_year'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   math_score             29 non-null     int64
#  1   reading_score          29 non-null     int64
#  2   writing_score          29 non-null     float64
#  3   placement_score        29 non-null     float64
#  4   club_join_year         29 non-null     int64
#  5   placement_offer_count  28 non-null     float64
# dtypes: float64(3), int64(3)
# memory usage: 1.5 KB

# %%
df['placement_offer_count'] = df['placement_offer_count'].fillna('1')
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           79             77           75.0            100.0            2019
# 1           74             86           69.0             75.0            2019
# 2           75             93           65.0             75.0            2021
# 3           63             84           76.0             90.0            2019
# 4           71             80           76.0             79.0            2020
# 5           90             92           64.0             89.0            2021
# 6           64             92           80.0            200.0            2020
# 7           50             98           80.0             81.0            2020
# 8           72             91           71.0             78.0            2018
# 9           76             87           76.0             80.0            2018
# 10          60             86           75.0             95.0            2019
# 11          76             97           60.0             84.0            2018
# 12          63             91           75.0             94.0            2018
# 13          62            100           75.0             82.0            2018
# 14          76             75           71.0             92.0            2020
# 15          73             98           61.0             92.0            2018
# 16          79             78           74.0             81.0            2019
# 17          63             97           68.0             81.0            2019
# 18          78             97           62.0             89.0            2021
# 19          69             94           67.0             96.0            2019
# 20          60             90           63.0            100.0            2019
# 21          79             97           25.0             76.0            2020
# 22          77             90           71.0             84.0            2020
# 23          74             75           69.0             96.0            2019
# 24          78             98           61.0             96.0            2018
# 25          60             91           79.0             81.0            2021
# 26          71             77           74.0             84.0            2018
# 27          73             84           74.0             88.0            2021
# 28          66             94           62.0             82.0            2021
#
#    placement_offer_count
# 0                    3.0
# 1                    2.0
# 2                    2.0
# 3                    3.0
# 4                    2.0
# 5                    3.0
# 6                    3.0
# 7                    2.0
# 8                    2.0
# 9                    2.0
# 10                   3.0
# 11                   2.0
# 12                   3.0
# 13                   2.0
# 14                   1.0
# 15                   3.0
# 16                     1
# 17                   2.0
# 18                   3.0
# 19                   3.0
# 20                   3.0
# 21                   2.0
# 22                   2.0
# 23                   1.0
# 24                   3.0
# 25                   2.0
# 26                   2.0
# 27                   3.0
# 28                   2.0

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            0
# placement_score          0
# club_join_year           0
# placement_offer_count    0
# dtype: int64

# %%
df.dtypes
# Out:
# math_score                 int64
# reading_score              int64
# writing_score            float64
# placement_score          float64
# club_join_year             int64
# placement_offer_count     object
# dtype: object

# %%
df['math_score'] = df['math_score'].astype('int64')
df['reading_score'] = df['reading_score'].astype('int64')
df['writing_score'] = df['writing_score'].astype('int64')
df['placement_score'] = df['placement_score'].astype('int64')
df['club_join_year'] = df['club_join_year'].astype('int64')
df['placement_offer_count'] = df['placement_offer_count'].astype('int64')

# %%
df.dtypes
# Out:
# math_score               int64
# reading_score            int64
# writing_score            int64
# placement_score          int64
# club_join_year           int64
# placement_offer_count    int64
# dtype: object

# %%
columns = ['math_score', 'reading_score', 'writing_score', 'placement_score']
df.boxplot(columns)
# Out:
# <Axes: >

# %%
np.where(df['math_score']<60)
# Out:
# (array([7], dtype=int64),)

# %%
np.where(df['math_score']>80)
# Out:
# (array([5], dtype=int64),)

# %%
np.where(df['reading_score']<75)
# Out:
# (array([], dtype=int64),)

# %%
np.where(df['reading_score']>95)
# Out:
# (array([ 7, 11, 13, 15, 17, 18, 21, 24], dtype=int64),)

# %%
np.where(df['writing_score']<60)
# Out:
# (array([21], dtype=int64),)

# %%
np.where(df['writing_score']>80)
# Out:
# (array([], dtype=int64),)

# %%
np.where(df['placement_score']<75)
# Out:
# (array([], dtype=int64),)

# %%
np.where(df['placement_score']>100)
# Out:
# (array([6], dtype=int64),)

# %%
np.where((df['placement_score']<75) & (df['placement_offer_count']>1))
# Out:
# (array([], dtype=int64),)

# %%
np.where(((df['placement_score']>75)&(df['placement_score']<=85))&((df['placement_offer_count']<2)|(df['placement_offer_count']>2)))
# Out:
# (array([16], dtype=int64),)

# %%
np.where((df['placement_score']>85)&(df['placement_offer_count']<3))
# Out:
# (array([14, 23], dtype=int64),)

# %%
df[(df['math_score']<60)|(df['math_score']>80)]
# Out:
#    math_score  reading_score  writing_score  placement_score  club_join_year  \
# 5          90             92             64               89            2021
# 7          50             98             80               81            2020
#
#    placement_offer_count
# 5                      3
# 7                      2

# %%
df[(df['reading_score']<75)|(df['reading_score']>95)]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 7           50             98             80               81            2020
# 11          76             97             60               84            2018
# 13          62            100             75               82            2018
# 15          73             98             61               92            2018
# 17          63             97             68               81            2019
# 18          78             97             62               89            2021
# 21          79             97             25               76            2020
# 24          78             98             61               96            2018
#
#     placement_offer_count
# 7                       2
# 11                      2
# 13                      2
# 15                      3
# 17                      2
# 18                      3
# 21                      2
# 24                      3

# %%
df[(df['writing_score']<60)|(df['writing_score']>80)]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 21          79             97             25               76            2020
#
#     placement_offer_count
# 21                      2

# %%
df[(df['placement_score']<75)|(df['placement_score']>100)]
# Out:
#    math_score  reading_score  writing_score  placement_score  club_join_year  \
# 6          64             92             80              200            2020
#
#    placement_offer_count
# 6                      3

# %%
df[(df['club_join_year']<2018)|(df['club_join_year']>2021)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_year, placement_offer_count]
# Index: []

# %%
df[(df['placement_score']<75) & (df['placement_offer_count']>1)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_year, placement_offer_count]
# Index: []

# %%
df[((df['placement_score']>75)&(df['placement_score']<=85))&((df['placement_offer_count']<2)|(df['placement_offer_count']>2))]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 16          79             78             74               81            2019
#
#     placement_offer_count
# 16                      1

# %%
df[(df['placement_score']>85)&(df['placement_offer_count']<3)]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 14          76             75             71               92            2020
# 23          74             75             69               96            2019
#
#     placement_offer_count
# 14                      1
# 23                      1

# %%
new_df1 = df[
    ((df.math_score>=60)&(df.math_score<=80))&
    ((df.reading_score>=75)&(df.reading_score<=95))&
    ((df.writing_score>=60)&(df.writing_score<=80))&
    ((df.placement_score>=75)&(df.placement_score<=100))&
    ((df.club_join_year>=2018)&(df.club_join_year<=2021))]
new_df1
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           79             77             75              100            2019
# 1           74             86             69               75            2019
# 2           75             93             65               75            2021
# 3           63             84             76               90            2019
# 4           71             80             76               79            2020
# 8           72             91             71               78            2018
# 9           76             87             76               80            2018
# 10          60             86             75               95            2019
# 12          63             91             75               94            2018
# 14          76             75             71               92            2020
# 16          79             78             74               81            2019
# 19          69             94             67               96            2019
# 20          60             90             63              100            2019
# 22          77             90             71               84            2020
# 23          74             75             69               96            2019
# 25          60             91             79               81            2021
# 26          71             77             74               84            2018
# 27          73             84             74               88            2021
# 28          66             94             62               82            2021
#
#     placement_offer_count
# 0                       3
# 1                       2
# 2                       2
# 3                       3
# 4                       2
# 8                       2
# 9                       2
# 10                      3
# 12                      3
# 14                      1
# 16                      1
# 19                      3
# 20                      3
# 22                      2
# 23                      1
# 25                      2
# 26                      2
# 27                      3
# 28                      2

# %%
new_df1[(new_df1['placement_score']<75)&(new_df1['placement_offer_count']>1)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_year, placement_offer_count]
# Index: []

# %%
new_df1[((new_df1['placement_score']>75)&(new_df1['placement_score']<=85))&((new_df1['placement_offer_count']<2)|(new_df1['placement_offer_count']>2))]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 16          79             78             74               81            2019
#
#     placement_offer_count
# 16                      1

# %%
new_df1[(new_df1['placement_score']>85)&(new_df1['placement_offer_count']<3)]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 14          76             75             71               92            2020
# 23          74             75             69               96            2019
#
#     placement_offer_count
# 14                      1
# 23                      1

# %%
new_df2 = new_df1[
    ((new_df1['placement_score']<75)&(new_df1['placement_offer_count']==1))|
    (((new_df1['placement_score']>=75)&(new_df1['placement_score']<=85))&(new_df1['placement_offer_count']==2))|
    ((new_df1['placement_score']>85)&(new_df1['placement_offer_count']==3))
]
new_df2
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           79             77             75              100            2019
# 1           74             86             69               75            2019
# 2           75             93             65               75            2021
# 3           63             84             76               90            2019
# 4           71             80             76               79            2020
# 8           72             91             71               78            2018
# 9           76             87             76               80            2018
# 10          60             86             75               95            2019
# 12          63             91             75               94            2018
# 19          69             94             67               96            2019
# 20          60             90             63              100            2019
# 22          77             90             71               84            2020
# 25          60             91             79               81            2021
# 26          71             77             74               84            2018
# 27          73             84             74               88            2021
# 28          66             94             62               82            2021
#
#     placement_offer_count
# 0                       3
# 1                       2
# 2                       2
# 3                       3
# 4                       2
# 8                       2
# 9                       2
# 10                      3
# 12                      3
# 19                      3
# 20                      3
# 22                      2
# 25                      2
# 26                      2
# 27                      3
# 28                      2

# %%
new_df2.shape
# Out:
# (16, 6)

# %%
#Data transformation
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()
scaling.fit_transform(new_df2[['math_score','reading_score','writing_score','placement_score']])
# Out:
# array([[1.        , 0.        , 0.76470588, 1.        ],
#        [0.73684211, 0.52941176, 0.41176471, 0.        ],
#        [0.78947368, 0.94117647, 0.17647059, 0.        ],
#        [0.15789474, 0.41176471, 0.82352941, 0.6       ],
#        [0.57894737, 0.17647059, 0.82352941, 0.16      ],
#        [0.63157895, 0.82352941, 0.52941176, 0.12      ],
#        [0.84210526, 0.58823529, 0.82352941, 0.2       ],
#        [0.        , 0.52941176, 0.76470588, 0.8       ],
#        [0.15789474, 0.82352941, 0.76470588, 0.76      ],
#        [0.47368421, 1.        , 0.29411765, 0.84      ],
#        [0.        , 0.76470588, 0.05882353, 1.        ],
#        [0.89473684, 0.76470588, 0.52941176, 0.36      ],
#        [0.        , 0.82352941, 1.        , 0.24      ],
#        [0.57894737, 0.        , 0.70588235, 0.36      ],
#        [0.68421053, 0.41176471, 0.70588235, 0.52      ],
#        [0.31578947, 1.        , 0.        , 0.28      ]])
